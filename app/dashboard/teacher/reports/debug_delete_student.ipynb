# %% [markdown]
# # Debugging Student Deletion Issue
#
# This notebook tracks the investigation into why students are not deleting.
#
# **Observations:**
# 1. `ApiService.dart` is hardcoded to `https://teacher-eight-chi.vercel.app`.
# 2. `start.sh` starts a local backend on port 3004.
# 3. If the user runs the app locally but the code points to Prod, they are testing against Prod.
# 4. If the Prod backend is outdated (missing endpoints), it will fail.
#
# **Validation Code:**
# Checking `ApiService.dart` imports and `baseUrl` property.
